# %% [markdown]
# # Intro

# %% [markdown]
# We are going to use a chocolate dataset collected from [kaggle](https://www.kaggle.com/rtatman/chocolate-bar-ratings/data), to perform some simple Data visualisation techniques.
# Numpy and Pandas library must be installed.
#
# **Numpy** - what is it?
#
# **Pandas** - what is it?
#
# Installed using `pip install pandas numpy`

# %% [markdown]
# First step is to initialise the data into a Pandas dataframe.
# So we import `os` to do os operations such as finding current filepath and opening files.
# `Numpy` and `pandas` modules are also imported.
#
# Then the `.csv` file is converted into a pandas dataframe.

# %%
import os, numpy, pandas as pd

filepath = os.sep.join(['data/flavors_of_cacao.csv'])
print(filepath)
data = pd.read_csv(filepath)
data.head()
# Out:
# data/flavors_of_cacao.csv
#   Company \n(Maker-if known) Specific Bean Origin\nor Bar Name   REF  \
# 0                   A. Morin                       Agua Grande  1876
# 1                   A. Morin                             Kpime  1676
# 2                   A. Morin                            Atsane  1676
# 3                   A. Morin                             Akata  1680
# 4                   A. Morin                            Quilla  1704
#
#    Review\nDate Cocoa\nPercent Company\nLocation  Rating Bean\nType  \
# 0          2016            63%            France    3.75
# 1          2015            70%            France    2.75
# 2          2015            70%            France    3.00
# 3          2015            70%            France    3.50
# 4          2015            70%            France    3.50
#
#   Broad Bean\nOrigin
# 0           Sao Tome
# 1               Togo
# 2               Togo
# 3               Togo
# 4               Peru

# %% [markdown]
# We can now easily inspect the data using some of the built-in pandas commands, such as number of rows, column names and data types within the dataframe.

# %%
# Number of rows
print("no. of rows = ",data.shape[0],"\n")

# Column names
print("the columns are",data.columns.tolist(),"\n")

# Data types
print(data.dtypes)
# Out:
# no. of rows =  1795
#
# the columns are ['Company\xa0\n(Maker-if known)', 'Specific Bean Origin\nor Bar Name', 'REF', 'Review\nDate', 'Cocoa\nPercent', 'Company\nLocation', 'Rating', 'Bean\nType', 'Broad Bean\nOrigin']
#
# Company \n(Maker-if known)            object
# Specific Bean Origin\nor Bar Name     object
# REF                                    int64
# Review\nDate                           int64
# Cocoa\nPercent                        object
# Company\nLocation                     object
# Rating                               float64
# Bean\nType                            object
# Broad Bean\nOrigin                    object
# dtype: object

# %% [markdown]
# We can drop the columns "REF" and "Review Date" because we can. Also, its also not super useful anyways.

# %%
data.drop(columns=['REF','Review\nDate'])
# Out:
#      Company \n(Maker-if known)   Specific Bean Origin\nor Bar Name  \
# 0                      A. Morin                         Agua Grande
# 1                      A. Morin                               Kpime
# 2                      A. Morin                              Atsane
# 3                      A. Morin                               Akata
# 4                      A. Morin                              Quilla
# 5                      A. Morin                            Carenero
# 6                      A. Morin                                Cuba
# 7                      A. Morin                        Sur del Lago
# 8                      A. Morin                      Puerto Cabello
# 9                      A. Morin                             Pablino
# 10                     A. Morin                              Panama
# 11                     A. Morin                          Madagascar
# 12                     A. Morin                              Brazil
# 13                     A. Morin                            Equateur
# 14                     A. Morin                            Colombie
# 15                     A. Morin                            Birmanie
# 16                     A. Morin                    Papua New Guinea
# 17                     A. Morin                               Chuao
# 18                     A. Morin                               Piura
# 19                     A. Morin                Chanchamayo Province
# 20                     A. Morin                Chanchamayo Province
# 1767            70%           Austria    3.50   Criollo, Trinitario
# 1768            70%           Austria    2.75     Nacional (Arriba)
# 1769            85%           Austria    2.75            Trinitario
# 1770            85%           Austria    3.00   Criollo, Trinitario
# 1771            70%           Austria    3.50   Criollo, Trinitario
# 1772            78%           Austria    3.50            Trinitario
# 1773            78%         Australia    3.75
# 1774            65%         Australia    3.25
# 1775            68%         Australia    3.50
# 1776            66%         Australia    3.50            Trinitario
# 1777            72%         Australia    3.75
# 1778            80%           Austria    2.75
# 1779            72%           Austria    3.50
# 1780            65%           Austria    3.50
# 1781            70%           Austria    3.00      Criollo (Amarru)
# 1782            70%           Austria    3.50      Criollo (Amarru)
# 1783            62%           Austria    3.75
# 1784            75%           Austria    3.00  Forastero (Nacional)
# 1785            75%           Austria    3.00   Criollo, Trinitario
# 1786            90%           Austria    3.25
# 1787            70%           Austria    3.75
# 1788            68%           Austria    3.25             Forastero
# 1789            58%           Austria    3.50
# 1790            70%           Austria    3.75
# 1791            65%           Austria    3.00             Forastero
# 1792            65%           Austria    3.50             Forastero
# 1793            62%           Austria    3.25
# 1794            65%           Austria    3.00
#
#       Broad Bean\nOrigin
# 0               Sao Tome
# 1                   Togo
# 2                   Togo
# 3                   Togo
# 4                   Peru
# 5              Venezuela
# 6                   Cuba
# 7              Venezuela
# 8              Venezuela
# 9                   Peru
# 10                Panama
# 11            Madagascar
# 12                Brazil
# 13               Ecuador
# 14              Colombia
# 15                 Burma
# 16      Papua New Guinea
# 17             Venezuela
# 18                  Peru
# 19                  Peru
# 20                  Peru
# 21               Bolivia
# 22                  Peru
# 23                  Peru
# 24                  Peru
# 25                  Fiji
# 26                  Fiji
# 27                  Fiji
# 28                  Fiji
# 29               Ecuador
# ...                  ...
# 1765              Belize
# 1766
# 1767          Madagascar
# 1768             Ecuador
# 1769            Trinidad
# 1770            Tanzania
# 1771            Tanzania
# 1772            Trinidad
# 1773     Solomon Islands
# 1774
# 1775             Bolivia
# 1776    Papua New Guinea
# 1777             Bolivia
# 1778
# 1779              Panama
# 1780
# 1781                Peru
# 1782                Peru
# 1783  Dominican Republic
# 1784             Ecuador
# 1785    Papua New Guinea
# 1786             Bolivia
# 1787  Dominican Republic
# 1788               Congo
# 1789
# 1790                Peru
# 1791               Congo
# 1792               India
# 1793               India
# 1794              Brazil
#
# [1795 rows x 7 columns]

# %% [markdown]
# Next lets count up the bean types.
# We can also do a mean, median, and quartiles for Cocoa Perentages just by using `.describe()`

# %%
beantypes = data['Bean\nType'].value_counts()
print(beantypes,"\n")

data['Cocoa\nPercent'] = data['Cocoa\nPercent'].str.replace('%', '')
cocoa_percent_int=pd.to_numeric(data['Cocoa\nPercent'],downcast='integer')
cocoa_percent_int.describe()
# Out:
#                             887
# Trinitario                  419
# Criollo                     153
# Forastero                    87
# Forastero (Nacional)         52
# Blend                        41
# Criollo, Trinitario          39
# Forastero (Arriba)           37
# Criollo (Porcelana)          10
# Trinitario, Criollo           9
# Forastero (Parazinho)         8
# Forastero (Arriba) ASS        6
# Beniano                       3
# Matina                        3
# EET                           3
# Nacional (Arriba)             3
# Criollo (Ocumare 61)          2
# Criollo, Forastero            2
# Amazon mix                    2
# Trinitario, Forastero         2
# Amazon, ICS                   2
# Trinitario (85% Criollo)      2
# Nacional                      2
# Forastero (Catongo)           2
# Criollo (Amarru)              2
# Criollo (Ocumare)             1
# Trinitario, TCGA              1
# Criollo, +                    1
# Forastero, Trinitario         1
# CCN51                         1
# Criollo (Wild)                1
# Forastero (Arriba) ASSS       1
# Forastero(Arriba, CCN)        1
# Criollo (Ocumare 67)          1
# Amazon                        1
# Trinitario (Amelonado)        1
# Trinitario (Scavina)          1
# Blend-Forastero,Criollo       1
# Trinitario, Nacional          1
# Criollo (Ocumare 77)          1
# Forastero (Amelonado)         1
# Name: Bean\nType, dtype: int64
# count    1795.000000
# mean       71.698329
# std         6.323118
# min        42.000000
# 25%        70.000000
# 50%        70.000000
# 75%        75.000000
# max       100.000000
# Name: Cocoa\nPercent, dtype: float64

# %% [markdown]
# Now we can make a scatterplot of the Rating given against Cocoa Strength. We need to import `matplotlib` to achieve this.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# A simple scatter plot with Matplotlib
ax = plt.axes()

ax.scatter(cocoa_percent_int, data['Rating'])

# Label the axes
ax.set(xlabel='Cocoa Strength',
       ylabel='Rating',
       title='Cocoa Strength vs Rating')
# Out:
# [Text(0,0.5,'Rating'),
#  Text(0.5,0,'Cocoa Strength'),
#  Text(0.5,1,'Cocoa Strength vs Rating')]

# %% [markdown]
# We can use pandas' `.value_counts()` to calculate the frequencies for example how many times a Company is repeated, this will give us how many different products they make.
#
# Using `matplotlib` again now we can make a bar chart, this time lets plot the top 6

# %%
bc = plt.axes()

Companyfreq=data['Company\xa0\n(Maker-if known)'].value_counts()
x=[] #init empty lists
y=[]
for i in range (0,5):
    x.append(Companyfreq.axes[0][i])
    y.append(Companyfreq[i])
    
bc.bar(x,y)
# Out:
# <Container object of 5 artists>

# %% [markdown]
# We can also use seaborn for plotting
#
# USE SEABORN for bar charts
# use four things?

# %% [markdown]
# We can also create multiple plots together. It can be useful in some cases I imagine.

# %%
# To create separate plots, use Pandas `.hist` method
axList = data.hist(bins=25)

# Add some x- and y- labels to first column and last row
for ax in axList.flatten():
    if ax.is_last_row():
        ax.set_xlabel('X axis')
        
    if ax.is_first_col():
        ax.set_ylabel('Boring label')

# %% [markdown]
# But we haven't used numpy yet? What's the point in even making trvial plots that can be made on excel? Well below is a randomly generated data plotted using `Seaborn`, it makes plots not easily do-able in excel.

# %%
from scipy.stats import kendalltau
import seaborn as sns
sns.set(style="ticks")

rs = np.random.RandomState(11)
x = rs.gamma(2, size=1000)
y = -.5 * x + rs.normal(size=1000)

sns.jointplot(x, y, kind="hex", stat_func=kendalltau, color="#4CB391")

# %% [markdown]
# We can't just end this with random data so lets make one more plot. Since we've introduced Seaborn, this time we will use it again and plot the counts of each ratings.

# %%
sns.countplot(x = 'Rating', data=data) #"Rating" is picked and plotted
